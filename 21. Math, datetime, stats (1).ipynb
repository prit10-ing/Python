# %%
# !pip install math
# Out:
# ERROR: Could not find a version that satisfies the requirement math (from versions: none)
# ERROR: No matching distribution found for math

# %% [markdown]
# ### Module

# %%
import math as mt  #aliase

# %%
mt.pi
# Out:
# 3.141592653589793

# %%
mt.factorial(5)
# Out:
# 120

# %%
mt.ceil(30.005)
# Out:
# 31

# %%
mt.floor(30.9999)
# Out:
# 30

# %%
mt.sqrt(20)
# Out:
# 4.47213595499958

# %%
mt.comb(8, 3)
# Out:
# 56

# %%
mt.perm(8, 3)
# Out:
# 336

# %%
mt.lcm(30, 20, 10)
# Out:
# 60

# %%
mt.pow(4,2)
# Out:
# 16.0

# %%
mt.isqrt(16)
# Out:
# 4

# %%
mt.radians(30)
# Out:
# 0.5235987755982988

# %%
import datetime

# %%
from datetime import date

# %%
today = date.today()

# %%
print("Today's date:", today)
# Out:
# Today's date: 2025-09-08

# %%
print("Formatted date:", today.strftime("%Y-%m-%d"))
# Out:
# Formatted date: 2025-09-08

# %%
date.today()
# Out:
# datetime.date(2025, 9, 8)

# %%
from datetime import time

current_time = time(14, 30, 45)
print("Current time:", current_time)
print("Formatted time:", current_time.strftime("%H:%M:%S"))
# Out:
# Current time: 14:30:45
# Formatted time: 14:30:45

# %%
current_time
# Out:
# datetime.time(14, 30, 45)

# %%
from datetime import datetime

now = datetime.now()
print("Current date and time:", now)
print("Formatted datetime:", now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Current date and time: 2025-09-08 14:03:14.058571
# Formatted datetime: 2025-09-08 14:03:14

# %%
from datetime import timedelta

delta = timedelta(days=5, hours=3)
print("Delta:", delta)
print("Total seconds in delta:", delta.total_seconds())
# Out:
# Delta: 5 days, 3:00:00
# Total seconds in delta: 442800.0

# %%
from datetime import datetime, timezone

now = datetime.now(timezone.utc)
print("Current UTC time:", now)
# Out:
# Current UTC time: 2025-09-08 08:34:35.367162+00:00

# %%
from datetime import date, time, datetime

d = date(2024, 7, 27)
t = time(15, 30, 45)
dt = datetime(2024, 7, 27, 15, 30, 45)

# %%
d.strftime("%Y-%m-%d")
# Out:
# '2024-07-27'

# %%
t.strftime("%H-%M-%S")
# Out:
# '15-30-45'

# %%
d.strftime("%Y-%b-%d")
# Out:
# '2024-Jul-27'

# %%
from datetime import datetime, timedelta

now = datetime.now()
tomorrow = now + timedelta(days=2)
difference = tomorrow - now
print("Difference:", difference)
# Out:
# Difference: 2 days, 0:00:00

# %%
now
# Out:
# datetime.datetime(2025, 9, 8, 14, 10, 6, 479077)

# %%
tomorrow
# Out:
# datetime.datetime(2025, 9, 10, 14, 10, 6, 479077)

# %%
from datetime import time

t = time(14, 30)
new_time = t.replace(minute=45)
print("Updated time:", new_time)
# Out:
# Updated time: 14:45:00

# %%
from datetime import datetime

now = datetime.now()
weekday = now.weekday()  # Monday is 0, Sunday is 6
week_number = now.isocalendar()[1]  # Week number of the year

print("Weekday (0=Monday, 6=Sunday):", weekday)
print("ISO calendar week number:", week_number)
# Out:
# Weekday (0=Monday, 6=Sunday): 0
# ISO calendar week number: 37

# %%
now
# Out:
# datetime.datetime(2025, 9, 8, 14, 12, 13, 208593)

# %%
weekday
# Out:
# 0

# %%
week_number
# Out:
# 37

# %%
from datetime import datetime, timedelta

# Schedule an event
event_date = datetime(2024, 7, 27, 15, 0)
reminder_time = event_date - timedelta(hours=1)
print("Reminder set for:", reminder_time)
# Out:
# Reminder set for: 2024-07-27 14:00:00

# %%
from datetime import datetime, timedelta

# Calculate the time between payments
payment_date = datetime(2024, 7, 27)
next_payment = payment_date + timedelta(days=30)
print("Next payment date:", next_payment)
# Out:
# Next payment date: 2024-08-26 00:00:00

# %%
import statistics as st

# %%
st.mean([2,3,4,5,5,6,7,7])
# Out:
# 4.875

# %%
st.mode([2,3,4,5,5,6,7,7])
# Out:
# 5

# %%
st.median([2,3,4,5,5,6,7,7])
# Out:
# 5.0

# %%
st.var([2,3,4,5,5,6,7,7])
